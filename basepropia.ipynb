# %% [markdown]
# <a href="https://colab.research.google.com/github/LizBarper/DiplomadoDatos2023/blob/main/basepropia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Lectura de archivo.

# %%
import pandas as pd

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My \Drive/Colab Notebooks
# Out:
# /content/drive/My Drive/Colab Notebooks

# %% [markdown]
# **Librerias viaual**

# %%
import plotly.express as px

# %%
import plotly.io as pio

# %% [markdown]
# **Lectura de Datos**

# %%
df=pd.read_excel('base1.xlsx')
df
# Out:
#      Clave_doc         Clave_art     Costo  Folio Ref_proveedor  Clave_prov  \
# 0        19976     ARTDELIMPIEZA   2160.00  19976       S 78170      100004
# 1        20003  GASOLINACOMERCIA  53543.00  20003  EAC 01939605         404
# 2        20004     VALESDESADMON   6174.00  20004  EAE 02162855         404
# 3        20003   CARGOADMONVALES   2222.03  20003  EAC 01939605         404
# 4        20004   CARGOADMONVALES    350.00  20004  EAE 02162855         404
# ...        ...               ...       ...    ...           ...         ...
# 1100     20468    IVAIMPORTACION     46.00  20468   BF-23016187        1099
# 1101     20468    IVAIMPORTACION   8857.00  20468   BF-23016187        1099
# 1102     20467  HONORARIOSIMPORT   1020.00  20467        A 2669        1099
# 1103     20463  FLETEIMPORTACION    133.25  20463    COD 401303        2103
# 1104     20463  FLETEIMPORTACION    253.00  20463    COD 401303        2103
#
# ...

# %%
df.shape
# Out:
# (1105, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1105 entries, 0 to 1104
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Clave_doc      1105 non-null   object
#  1   Clave_art      1105 non-null   object
#  2   Costo          1105 non-null   float64
#  3   Folio          1105 non-null   int64
#  4   Ref_proveedor  1105 non-null   object
#  5   Clave_prov     1105 non-null   int64
#  6   Linea          1103 non-null   object
#  7   Cantidad       1105 non-null   int64
#  8   Fecha_doc      1105 non-null   datetime64[ns]
#  9   Descripcion    1105 non-null   object
#  10  Nombre_prov    1105 non-null   object
#  11  Almacen        1105 non-null   int64
#  12  Fecha_elab     1105 non-null   datetime64[ns]
#  13  Subtotal       1105 non-null   float64
# dtypes: datetime64[ns](2), float64(2), int64(4), object(6)
# memory usage: 121.0+ KB

# %%
df['Almacen'].unique()
# Out:
# array([100,  10,   1])

# %%
df4=df[df.Almacen==1]
df4
# Out:
#      Clave_doc         Clave_art     Costo  Folio Ref_proveedor  Clave_prov  \
# 91     CDAK108     100002131-012   1917.16    108      92255250      101013
# 92     CDAK108     100001581-003   1444.59    108      92255250      101013
# 126    MEX2788         300400010    355.00   2788           402      101130
# 127    MEX2787         300400010    355.00   2787           403      101130
# 236     USTE92    XLP-S1-LEDR1AT    431.13     92        953284         205
# 327    CHNS423  HZCAS300HTMOWT50   3859.47    423    1062301032      101153
# 328    CHNS423  HZCAS210HTHOWT50   4989.08    423    1062301032      101153
# 446    MEX2811         600400048   1692.00   2811     CFDI 8258         904
# 470    CHNS424     117400027-001    688.98    424   21502310201      100993
# 471    CHNS424     117400040-001    599.53    424   21502310201      100993
# 478    CHNS425          PSLC80-E   6816.09    425  NANUS7151207      100652
# ...

# %%
df4['Nombre_prov'].unique()
# Out:
# array(['BELUCE CANADA INC.', 'ARTURO LOPEZ LENA VILLASANA',
#        'BEST LIGHTING PRODUCTS INC.', 'VENAS INTERNATIONAL CO LIMITED',
#        'TEURA ILUMINACION SA DE CV', 'SHENZHEN HUADIAN LIGHTING CO LTD',
#        'SHENZHEN SRESKY CO., LTD'], dtype=object)

# %%
df4['Nombre_prov'].nunique()
# Out:
# 7

# %%
fig = px.histogram(df4, x = 'Nombre_prov')
fig.update_layout(
    xaxis_title = 'Proveedor',
    yaxis_title = 'Cantidad de compras 2023',
#    title_text = format_title('Histograma', ''),
    template = 'plotly_white',
    ) 
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df4.groupby(['Fecha_doc','Nombre_prov']).Clave_art.nunique()
# Out:
# Fecha_doc   Nombre_prov
# 2023-01-05  BELUCE CANADA INC.                  2
# 2023-01-06  ARTURO LOPEZ LENA VILLASANA         1
# 2023-01-23  BEST LIGHTING PRODUCTS INC.         1
# 2023-01-27  VENAS INTERNATIONAL CO LIMITED      2
# 2023-02-08  TEURA ILUMINACION SA DE CV          1
# 2023-02-10  SHENZHEN HUADIAN LIGHTING CO LTD    2
# 2023-02-13  SHENZHEN SRESKY CO., LTD            3
# 2023-02-20  VENAS INTERNATIONAL CO LIMITED      1
# 2023-02-23  BELUCE CANADA INC.                  2
# 2023-03-13  VENAS INTERNATIONAL CO LIMITED      1
# 2023-03-21  BELUCE CANADA INC.                  8
#             VENAS INTERNATIONAL CO LIMITED      1
# 2023-03-23  BELUCE CANADA INC.                  1
# 2023-03-24  SHENZHEN HUADIAN LIGHTING CO LTD    1
#             VENAS INTERNATIONAL CO LIMITED      1
# 2023-03-30  VENAS INTERNATIONAL CO LIMITED      4
# 2023-04-10  SHENZHEN HUADIAN LIGHTING CO LTD    1
# Name: Clave_art, dtype: int64

# %%
df5=df4[df.Clave_prov==101153]
df5
# Out:
# <ipython-input-53-7f44fda8c3a1>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df5=df4[df.Clave_prov==101153]
#      Clave_doc         Clave_art     Costo  Folio Ref_proveedor  Clave_prov  \
# 327    CHNS423  HZCAS300HTMOWT50   3859.47    423    1062301032      101153
# 328    CHNS423  HZCAS210HTHOWT50   4989.08    423    1062301032      101153
# 592    CHNS427  HZCAS310HTMOWT50   8384.72    427    1062302009      101153
# 814    CHNS430  HZCAS320HTMOWT50   9701.75    430    1062302052      101153
# 886    CHNS431  HZCAS320HTMOWT50  10258.49    431   1062302052*      101153
# 930    CHNS433         117400032   1133.86    433    1062303010      101153
# 1008   CHNS435         117400033   1444.39    435    1062303028      101153
# 1009   CHNS436  WPLED45WWT50KUNV   1203.66    436    1062303043      101153
# 1011   CHNS436  HZCAS310HTLOWT50   7499.71    436    1062303043      101153
# ...

# %%
df5.describe()
# Out:
#               Costo       Folio  Clave_prov    Cantidad  Almacen  \
# count     10.000000   10.000000        10.0   10.000000     10.0
# mean    5338.235000  431.000000    101153.0   70.800000      1.0
# std     3490.147322    5.163978         0.0   72.883164      0.0
# min     1133.860000  423.000000    101153.0    1.000000      1.0
# 25%     2048.160000  427.750000    101153.0   27.000000      1.0
# 50%     4948.150000  432.000000    101153.0   46.000000      1.0
# 75%     8163.467500  435.750000    101153.0   84.500000      1.0
# max    10258.490000  436.000000    101153.0  200.000000      1.0
#
#            Subtotal
# count      10.000000
# mean   460347.469000
# std    295984.798555
# min     10258.490000
# 25%    242298.720000
# 50%    512727.745000
# 75%    741198.725000
# max    786191.720000

# %%
fig2 = px.histogram(df5, x = 'Descripcion')
fig2.update_layout(
    xaxis_title = 'ITEM',
    yaxis_title = 'Cantidad de compras 2023',
#    title_text = format_title('Histograma', ''),
    template = 'plotly_white',
    ) 
fig2
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig3 = px.bar(df5, x = 'Descripcion', y = 'Cantidad')
fig3
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
