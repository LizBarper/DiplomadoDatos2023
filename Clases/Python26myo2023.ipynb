# %%
import pandas as pd
from sklearn.datasets import fetch_california_housing

# %%
california=fetch_california_housing()
df=pd.DataFrame(california.data,columns=california.feature_names)
df['target']=california.target
df.head
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e4ffed284949> in <cell line: 1>()
# ----> 1 california=fetch_california_housing()
#       2 df=pd.DataFrame(california.data,columns=california.feature_names)
#       3 df['target']=california.target
#       4 df.head
#
# NameError: name 'fetch_california_housing' is not defined
